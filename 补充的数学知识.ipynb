# %% [markdown]
# ## 说明
#
# 书中涉及到大量的高等数学、线性代数和概率论与数理统计的知识。在本科的这三门课程中学的内容不能完全覆盖书中需要的知识点。下面是我的补充。
#
# ### 一、线性代数求导规则
#
# 书上用到了很多向量和矩阵的求导，这里介绍一下：
#
# #### 1. 对向量求导
#
# $$\begin{align}
# \frac{\partial \mathbf{Ax}}{\partial \mathbf{x}} &= \mathbf{A}^\text{T}\\
# \frac{\partial \mathbf{Ax}}{\partial \mathbf{x}^\text{T}} &= \mathbf{A}\\
# \frac{\partial \mathbf{x}^\text{T}\mathbf{A}}{\partial \mathbf{x}} &= \mathbf{A}\\
# \frac{\partial \mathbf{x}^\text{T}\mathbf{A}\mathbf{x}}{\partial \mathbf{x}} &= (\mathbf{A}^\text{T} + \mathbf{A})\mathbf{x} \\
# \frac{\partial \mathbf{x\cdot x}}{\partial \mathbf{x}} &= \frac{\mathbf{x}^\text{T}\mathbf{x}}{\partial \mathbf{x}} = 2\mathbf{x}\\
# \frac{\partial \mathbf{w\cdot x}}{\partial \mathbf{x}} &= \frac{\partial \mathbf{w}^\text{T}\mathbf{x}}{\partial \mathbf{x}} = \mathbf{w}
# \end{align}$$
#
# #### 2. 对矩阵求导
#
# 对矩阵求导规则比较复杂，这篇文章写的很好：[【必读】3分钟带你了解标量对矩阵求导方法](https://zhuanlan.zhihu.com/p/279209775)。
#
# 另外我再总结一下书中证明要用到的的公式（如果你按照上面文章的方法学会了对矩阵求导的通用方法，可以很容易自己证明出来）
#
# $$\begin{array}
# \\d(\mathbf{AX}) = \mathbf{A}d\mathbf{X}\\
# \frac{\partial tr(\mathbf{X}^\text{T}\mathbf{A}\mathbf{X})}{\partial \mathbf{X}} = (\mathbf{A}^\text{T} + \mathbf{A})\mathbf{X}
# \end{array}$$
#
# ### 二、超空间几何
#
# #### 1. 点到超平面距离
#
# 假设在$n$维空间中，有超平面$\mathbf{w}\cdot \mathbf{x} + b = 0$，有一点$\mathbf{x}_0$。
#
# 则点到超平面的距离为：
#
# $$d = \frac{|\mathbf{w} \cdot \mathbf{x}_0 + b|}{||\mathbf{w}||}$$
#
# #### 2. 平行的超平面的距离
#
# 假设在$n$维空间中，有两个平行的超平面
#
# $$\mathbf{w}\cdot \mathbf{x} + b_1 = 0\\
#  \mathbf{w}\cdot \mathbf{x} + b_2 = 0$$
#
# 因为平行的超平面的权向量（$\mathbf{w}$向量）一定成比例，所以上面的公式把两个超平面的权向量化成一样的了，这时就只有$b$不同。
#
# 则两个超平面之间的距离为：
#
# $$d = \frac{|b_1-b_2|}{||\mathbf{w}||}$$
#
# ### 三、进阶版拉格朗日算子法（求多元函数条件极值）
#
# #### 1. 自变量是向量的多元函数
#
# 高数中学的拉格朗日算子法的条件只能是等式，下面给出条件有不等式的求法：
#
# 假设在约束条件$g(\mathbf{x})\leqslant 0$的情况下，求多元函数$f(\mathbf{x})$的极值。
#
# 1. 写出拉格朗日函数
#
# $$
# \mathscr{L}(\mathbf{x}) = f(\mathbf{x}) + \lambda g(\mathbf{x})
# $$
#
# 2. 写出条件不等式（KKT条件）
#
# $$\begin{align}
# \frac{\partial\mathscr{L}}{\partial\mathbf{x}} = \frac{\partial f}{\partial\mathbf{x}} + \lambda\frac{\partial g}{\partial\mathbf{x}} &= 0 \\
# \frac{\partial\mathscr{L}}{\partial \lambda} = g(\mathbf{x}) &\leqslant 0 \\
# \lambda &\geqslant 0 \\
# \lambda g(\mathbf{x}) &= 0
# \end{align}$$
#
# 这组不等式也叫KKT条件
#
# 3. 求解KKT条件
#
# 如果有多个约束条件也是同理，把KKT条件扩展一下就行。
#
# #### 2. 自变量是矩阵的函数
#
# 自变量是矩阵可能不好理解，但是教材162页的公式用到了这个方法。
#
# 自变量是矩阵时就把上面的公式中的常数$\lambda$换成对角阵$\boldsymbol{\Lambda}$，自变量向量$\mathbf{x}$换成矩阵$\mathbf{X}$即可，其他都不变。这里就不再赘述了。
